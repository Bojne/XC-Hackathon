# %%
import pandas as pd
import numpy as numpy
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
# import csv
# import os
# # data = pd.read_csv('/Users/ah-bau/Desktop/Hackathon/newtpe_edu_subset.csv')
# # d1 = pd.read_csv("try.csv")
# data = pd.read_csv("https://quality.data.gov.tw/dq_download_csv.php?nid=8409&md5_url=68bbb58d1558460e01c2b4fd8f6540d0")

# %%
df = pd.read_csv('NTPedu2.csv')
ch_index = df[0:1] 
type(ch_index)
# Out:
# pandas.core.frame.DataFrame

# %%
xindian = df[487:556]  #共69筆（有69個里）
xindian.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 487 to 555
# Data columns (total 50 columns):
# statistic_yyy                                  69 non-null object
# site_id                                        69 non-null object
# village                                        69 non-null object
# edu_age_15up_total                             69 non-null object
# edu_doctor_graduated_m                         69 non-null object
# edu_doctor_graduated_f                         69 non-null object
# edu_doctor_ungraduated_m                       69 non-null object
# edu_doctor_ungraduated_f                       69 non-null object
# edu_master_graduated_m                         69 non-null object
# edu_master_graduated_f                         69 non-null object
# edu_master_ungraduated_m                       69 non-null object
# edu_master_ungraduated_f                       69 non-null object
# edu_university_graduated_m                     69 non-null object
# edu_university_graduated_f                     69 non-null object
# edu_university_ungraduated_m                   69 non-null object
# edu_university_ungraduated_f                   69 non-null object
# edu_juniorcollege_2ys_graduated_m              69 non-null object
# edu_juniorcollege_2ys_graduated_f              69 non-null object
# edu_juniorcollege_2ys_ungraduated_m            69 non-null object
# edu_juniorcollege_2ys_ungraduated_f            69 non-null object
# edu_juniorcollege_5ys_final2y_graduated_m      69 non-null object
# edu_juniorcollege_5ys_final2y_graduated_f      69 non-null object
# edu_juniorcollege_5ys_final2y_ungraduated_m    69 non-null object
# edu_juniorcollege_5ys_final2y_ungraduated_f    69 non-null object
# edu_juniorcollege_5ys_first3y_ungraduated_m    69 non-null object
# edu_juniorcollege_5ys_first3y_ungraduated_f    69 non-null object
# edu_senior_graduated_m                         69 non-null object
# edu_senior_graduated_f                         69 non-null object
# edu_senior_ungraduated_m                       69 non-null object
# edu_senior_ungraduated_f                       69 non-null object
# edu_seniorvocational_graduated_m               69 non-null object
# edu_seniorvocational_graduated_f               69 non-null object
# edu_seniorvocational_ungraduated_m             69 non-null object
# edu_seniorvocational_ungraduated_f             69 non-null object
# edu_junior_graduated_m                         69 non-null object
# edu_junior_graduated_f                         69 non-null object
# edu_junior_ungraduated_m                       69 non-null object
# edu_junior_ungraduated_f                       69 non-null object
# edu_juniorvocational_graduated_m               69 non-null object
# edu_juniorvocational_graduated_f               69 non-null object
# edu_juniorvocational_ungraduated_m             69 non-null object
# edu_juniorvocational_ungraduated_f             69 non-null object
# edu_primary_graduated_m                        69 non-null object
# edu_primary_graduated_f                        69 non-null object
# edu_primary_ungraduated_m                      69 non-null object
# edu_primary_ungraduated_f                      69 non-null object
# edu_selftaughtl_m                              69 non-null object
# edu_selftaughtl_f                              69 non-null object
# edu_illiterate_m                               69 non-null object
# edu_illiterate_f                               69 non-null object
# dtypes: object(50)
# memory usage: 27.0+ KB

# %%
x10 = xindian[0:10]
x10
# Out:
# pandas.core.frame.DataFrame

# %%
groups = ["Movies", "Sports", "Coding", "Fishing", "Dancing", "cooking"]  
num = [46, 8, 12, 12, 6, 58]

dict = {"groups": groups,  
        "num": num
       }

select_df = pd.DataFrame(dict)
print(select_df)
print(select_df.iloc[0, 1]) # 第一列第二欄：組的人數  
print("---")  
print(select_df.iloc[0:2,1:]) # 第一列：組的組名與人數  
print("---")  
# print(select_df.iloc[:,1]) # 第二欄：各組的人數  
# print("---")  
# print(select_df["num"]) # 各組的人數  
# print("---")  
# print(select_df.num) # 各組的人數
# Out:
#     groups  num
# 0   Movies   46
# 1   Sports    8
# 2   Coding   12
# 3  Fishing   12
# 4  Dancing    6
# 5  cooking   58
# 46
# ---
#    num
# 0   46
# 1    8
# ---

# %%
# %pylab inline
xum = xindian['edu_university_graduated_m'] #大學男生@新店
xuf = xindian['edu_university_graduated_f'] #大學女生@新店
xum = xum.astype(float)
xum.plot()
xuf = xuf.astype(float)
xuf.plot()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
xum.hist()
xuf.hist()

# %%
xh = xindian[1:69] #h for histogram
xhuni = xh[['edu_university_graduated_m','edu_university_graduated_f']].astype(float)
# x1_10 = xindian[2:10].astype(float)
xhuni = xhuni.sort_values(by=['edu_university_graduated_m']) #照男生的
xhuni.plot.bar(stacked=True)

# %%
matplotlib.get_configdir()
# Out:
# '/Users/ah-bau/.matplotlib'

# %%
matplotlib.font_manager.FontProperties().get_family()
# Out:
# ['sans-serif']

# %%
from matplotlib import rcParams

rcParams['font.sans-serif'] = ['SimHei']

rcParams['font.family'] ='sans-serif'

# %%
import matplotlib
matplotlib.rcParams['font.sans-serif'] = 'SimHei'
# names = ["大同里","江陵里","寶興里","寶安里","信義里","忠孝里","大鵬里","太平里","頂城里"]
# xhuni = xhuni.set_index([names])

# %%
gd = pd.read_csv('grades.csv')
gd_small=gd[1:10]
gd_small = gd_small.set_index([['ㄧ','二','三','四','五','六','七','八','九']])
gd_small.plot.bar(stacked=True)
gd_small
# Out:
#     姓名  國文  英文  數學  自然  社會
# ㄧ  胡玉華  10  10  10   8   9
# 二  黃淑婷  13  15   8  11  14
# 三  陳上紫  10  10   8   9  14
# 四  崔靜成  13  12  14  12  13
# 五  張雅岳  13  12  12  12   8
# 六  梁俊翔  11  13  10  10  14
# 七  林金鳳   8   9  10  10   8
# 八  許協旺   9   9  12  10  10
# 九  郭雅惠  10  15  12  11   9

# %%
matplotlib.font_manager.FontProperties().get_family()
# Out:
# ['sans-serif']
