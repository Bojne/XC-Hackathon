# %%
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
import xlrd
import numpy as np

# %%
pf = pd.read_excel("./Data/105_base0.xls")
df =pd.DataFrame(pf)
df1 = df[2:]
df1.head()
# Out:
#   高級中等學校校別概況    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 2        NaN           NaN      專任教師數        NaN        NaN      兼任教師數
# 3        NaN           NaN         總計          男          女         總計
# 4     400144  國立臺灣戲曲學院附設高職         76         31         45        222
# 5     140222  國立臺東專科學校附設高職         82         44         38         27
# 6     010301    國立華僑高級中等學校        138         52         86          9
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 2        NaN        NaN        職員數        NaN         NaN         班級數
# 3          男          女         總計          男           女         NaN
# 4        126         96          0          0           0          21
# 5         19          8          0          0           0          36
# 6          3          6         30          8          22          48
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17
# 2         學生數         NaN         NaN     上學年畢業生數         NaN         NaN
# 3          總計           男           女          總計           男           女
# 4         444         144         300         132          40          92
# 5         971         698         273         210         132          78
# 6        1596         714         882         530         251         279

# %%
df1.columns = ['c1','c2','c3','c4','c5','c6','c7','c8','c9','c10','c11','c12','c13','c14','c15','c16','c17']
df1
df2 = df1[2:]
df3 = df2.astype(float)
df3.sum()
# Out:
# 250172.0
