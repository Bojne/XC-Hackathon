# %%
import pandas as pd
import numpy as numpy
# %matplotlib inline
# %pylab inline
import matplotlib
import matplotlib.pyplot as plt
pylab.rcParams['figure.figsize'] = (20, 8)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tpe105 = pd.read_csv('105_basec.csv')
tpe105.head()
tpe105.columns
tpess105 = tpe105[tpe105.縣市名稱 == '台北市']
tpess105.head()
print(tpess.shape)
tpe105_number = tpess105[['1年級男學生數', '1年級女學生數', '2年級男學生數', '2年級女學生數','3年級男學生數', '3年級女學生數', '4年級男學生數', '4年級女學生數', '5年級男學生數', '5年級女學生數','6年級男學生數', '6年級女學生數']].astype(float)
tpe105_number.head()
tpe105_number["學生人數"] = tpe105_number.sum(axis=1)
tpe105_number
# pylab.ylim([0,3500])
# tpess_number.sort_values('學生人數')['學生人數'].plot.bar()
# Out:
# (154, 32)
#      1年級男學生數  1年級女學生數  2年級男學生數  2年級女學生數  3年級男學生數  3年級女學生數  4年級男學生數  4年級女學生數  \
# 0       47.0     64.0     55.0     51.0     44.0     61.0     50.0     52.0
# 1       83.0    101.0     99.0    106.0     94.0     93.0     89.0     97.0
# 2      216.0    206.0    244.0    207.0    269.0    231.0    232.0    249.0
# 3      126.0    112.0    130.0    120.0    155.0    146.0    157.0    115.0
# 4      118.0     96.0    124.0     95.0    121.0     83.0    129.0     78.0
# 5       50.0     57.0     42.0     43.0     57.0     58.0     57.0     47.0
# 6       37.0     37.0     45.0     31.0     30.0     34.0     32.0     21.0
# 7       98.0     79.0     95.0     99.0     95.0     84.0     83.0     90.0
# 8       96.0     77.0     82.0     71.0     89.0     81.0     92.0     83.0
# 9       51.0     37.0     39.0     38.0     39.0     50.0     35.0     39.0
# 10     151.0    124.0    168.0    154.0    154.0    161.0    168.0    143.0
# 11      38.0     53.0     54.0     42.0     57.0     61.0     56.0     49.0
# 12      66.0     62.0     72.0     69.0     84.0     76.0     75.0     61.0
# 13      74.0     67.0     84.0     64.0     73.0     67.0     76.0     68.0
# 14      59.0     62.0     73.0     67.0     66.0     75.0     71.0     63.0
# 15      41.0     30.0     52.0     31.0     41.0     35.0     36.0     30.0
# 16     186.0    165.0    189.0    164.0    181.0    179.0    164.0    172.0
# 17      89.0     89.0     94.0     90.0     81.0    101.0     95.0     87.0
# 18     161.0    139.0    147.0    153.0    158.0    143.0    155.0    145.0
# 19      52.0     32.0     47.0     37.0     38.0     36.0     32.0     25.0
# 20      62.0     50.0     66.0     40.0     64.0     60.0     60.0     46.0
# 21     104.0     99.0    105.0    132.0    121.0    113.0    136.0     95.0
# 22      93.0     78.0     91.0     70.0     98.0     73.0     98.0     86.0
# 23     125.0    113.0    123.0     98.0    138.0    105.0    134.0     91.0
# 24     121.0    115.0    126.0    102.0    167.0    131.0    129.0    128.0
# 25     205.0    179.0    195.0    194.0    231.0    181.0    203.0    190.0
# 26     107.0     97.0    118.0     82.0     99.0    111.0    112.0     86.0
# 27      64.0     78.0     81.0     62.0     78.0     95.0     63.0    100.0
# 28      38.0     30.0     30.0     31.0     31.0     27.0     32.0     29.0
# 29      33.0     24.0     31.0     29.0     35.0     22.0     27.0     27.0
# ..       ...      ...      ...      ...      ...      ...      ...      ...
#
# 29      32.0     20.0     29.0     21.0   330.0
# ..       ...      ...      ...      ...     ...
# 122     20.0      6.0     18.0     15.0   148.0
# 123     37.0     43.0     36.0     25.0   424.0
# 124      5.0      7.0      7.0      6.0    81.0
# 125      4.0      5.0      3.0      6.0    56.0
# 126    138.0    112.0    124.0    129.0  1453.0
# 127     12.0      4.0     10.0      9.0   113.0
# 128    114.0     97.0    111.0     91.0  1169.0
# 129     53.0     45.0     54.0     61.0   585.0
# 130    145.0    125.0    126.0    135.0  1571.0
# 131     23.0     18.0     16.0     22.0   226.0
# 132     39.0     26.0     35.0     35.0   406.0
# 133     32.0     27.0     28.0     34.0   402.0
# 134     83.0     70.0     73.0     63.0   819.0
# 135     29.0     20.0     26.0     34.0   339.0
# 136    133.0    112.0    125.0    124.0  1501.0
# 137    104.0     99.0    139.0    119.0  1224.0
# 138     48.0     30.0     47.0     43.0   465.0
# 139    231.0    197.0    224.0    190.0  2437.0
# 140     78.0     89.0    115.0     80.0  1095.0
# 141      6.0      4.0      4.0      6.0    54.0
# 142     43.0     17.0     45.0     30.0   400.0
# 143     10.0      5.0      9.0      5.0    71.0
# 144     13.0      5.0     10.0      8.0   111.0
# 145     14.0     13.0     15.0     13.0   139.0
# 146     25.0     18.0     24.0     21.0   259.0
# 147     37.0     18.0     34.0     30.0   336.0
# 148     16.0     23.0     17.0     19.0   259.0
# 149     43.0     39.0     41.0     56.0   538.0
# 150     49.0     47.0     59.0     58.0   607.0
# 151    133.0    136.0    132.0    129.0  1561.0
#
# [152 rows x 13 columns]

# %%
import pylab
# pylab.ylim([0,3500])

tpe95 = pd.read_csv('95_basee.csv')
tpe95.head()
tpe95.columns
tpe95.shape
tpe105 = tpe105.drop([59,137])
tpess95 = tpe95[tpe95.縣市名稱 == '台北市']
tpe95_number = tpess95[['一年級男', '一年級女', '二年級男', '二年級女', '三年級男', '三年級女', '四年級男', '四年級女', '五年級男', '五年級女','六年級男', '六年級女']].astype(float)
tpe95_number.head()
tpe95_number["學生人數"] = tpess_number.sum(axis=1)
tpe95_number
tpe95_number = tpe95_number[['一年級男', '一年級女', '二年級男', '二年級女', '三年級男', '三年級女', '四年級男', '四年級女', '五年級男', '五年級女','六年級男', '六年級女','學生人數']].astype(float)

# tpe95_number.add





tpe95_number['diff'] = tpe95_number.學生人數 - tpe105_number.學生人數
tpe95_number = tpe95_number[['學生人數','diff']]
# tpe95_number.to_csv('fuck.csv')
print(tpe105[tpe105.學校代碼.isin(tpe95.學校代碼)==False].學校名稱)
print(tpe95[tpe95.學校代碼.isin(tpe105.學校代碼)==False].學校名稱)

# tpe105_number.diff < 0 =
# Out:
# RangeIndex(start=0, stop=154, step=1)

# %%
pylab.ylim([0,3500])
tpe95_number.sort_values('縣市名稱')['縣市名稱'].plot.bar()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '縣市名稱'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-eb8b5250dc83> in <module>()
#       1 pylab.ylim([0,3500])
# ----> 2 tpe95_number.sort_values('縣市名稱')['縣市名稱'].plot.bar()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3184
#    3185             by = by[0]
# -> 3186             k = self.xs(by, axis=other_axis).values
#    3187             if k.ndim == 2:
#    3188
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    2021
#    2022         if axis == 1:
# -> 2023             return self[key]
#    2024
#    2025         self._consolidate_inplace()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '縣市名稱'

# %%
ss.head()

# %%
print('106減少學校，不在tpessinfo裡面')
print (tpess[tpess.學校代碼.isin(tpess_info.學校代碼)==False].學校名稱)

print('106新增學校，不在tpessinfo裡面')

print (tpess_info[tpess_info.學校代碼.isin(tpess.學校代碼)==False].學校名稱) 
ss_number = tpess_info[['1年級男學生數', '1年級女學生數', '2年級男學生數', '2年級女學生數','3年級男學生數', '3年級女學生數', '4年級男學生數', '4年級女學生數', '5年級男學生數', '5年級女學生數','6年級男學生數', '6年級女學生數']].astype(float)
ss_number["學生人數"] = ss_number.sum(axis=1)
ss_number 

# ss_number["學生人數"] = ss_number['學生人數']-tpess_number['學生人數']
ss_number["學生人數"]

# %%
#砍掉多餘的學校
tpess = tpess[tpess.學校名稱 !='國立臺灣戲曲學院(國小)']
tpess = tpess[tpess.學校名稱 !='私立奎山實驗高中附設國小部']
tpess.shape

tpess_info = tpess_info[tpess_info.學校名稱 !='市立和平實驗國小' ]
tpess_info.shape
tpess_info.head()

# %%
tpess_info.地址

# %%
#合併info到tpess

# %%
tp104f = pd.read_csv('./Data/104_Taipei_female.csv') 
tp104m = pd.read_csv('./Data/104_Taipei_male.csv')
tp105f = pd.read_csv('./Data/105_Taipei_female.csv') 
tp105m = pd.read_csv('./Data/105_Taipei_male.csv')
tax = pd.read_csv('./Data/tax_tpe.csv') 
pop = pd.read_csv('./Data/105台北新北人口.csv')
tp_pop = pop[1033:]
newtax = tax[tax.村里 != '其　他']
newtax = newtax[newtax.村里 != '合　計']
print (tp104f.shape, tp104m.shape, tp105f.shape, tp105m.shape,newtax.shape,tp_pop.shape)
# tp104f['village']
# tp105f['village'].value_counts()

# %%
tp105f[0:1]

# %%
# tp105f = tp105f[1:]
# tp105m = tp105m[1:] 
# 去掉中文欄
tp105m.shape

# %%
# print(tax.鄉鎮市區.value_counts())
# print(tp105f.site_id.value_counts())

# %%
gb_tp105f = tp105f
gb_tp105f['site_id'].value_counts()

gb_tp105f = gb_tp105f.groupby('site_id').aggregate('sum')
gb_tp105f.head()

# %%
# simple_h_tp105f.head()
little_school_tp105f =  tp105f[['site_id', 'village','edu_primary_graduated_f','edu_junior_graduated_f']]
selfteach_tp105f = tp105f[['site_id', 'village','edu_selftaughtl_f']]

# %%
simple_h_tp105f = tp105f[['site_id', 'village','edu_doctor_graduated_f','edu_master_graduated_f','edu_university_graduated_f','edu_senior_graduated_f','edu_junior_graduated_f']]
simple_h_tp105f = simple_h_tp105f[1:]
simple_h_tp105f = simple_h_tp105f[['edu_doctor_graduated_f','edu_master_graduated_f','edu_university_graduated_f','edu_senior_graduated_f','edu_junior_graduated_f']].astype(float)

# %%
simple_h_tp105f.plot.scatter(x='edu_senior_graduated_f',y='edu_university_graduated_f')

# %%
import matplotlib.pyplot as plt

# Get current size
fig_size = plt.rcParams["figure.figsize"]

# Prints: [8.0, 6.0]
print "Current size:", fig_size

# Set figure width to 12 and height to 9
fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size

# %%
simple_h_tp105f = simple_h_tp105f[['edu_doctor_graduated_f','edu_master_graduated_f','edu_senior_graduated_f','edu_junior_graduated_f']].astype(float)

simple_h_tp105f.plot.line()

# %%
simple_h_tp105f.plot.scatter(x='edu_senior_graduated_f',y='edu_university_graduated_f')

# %%
simple_h_tp105f = simple_h_tp105f.sort_values(by=['edu_junior_graduated_f']) #照男生的排序
simple_h_tp105f.plot.line()

# %%
selfteach_tp105f[1:].edu_selftaughtl_f.astype(float).describe()

# %%
tp105m["site_id"]
#各區有幾個里

# %%
tp104f.iloc[1:5,0:4]
# tp104f_gradratio =
