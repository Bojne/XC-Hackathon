# %% [markdown]
# # 教育人口資料分析：新店
# ## 這份文件提供分析案例，也可以複製同樣的方法到不同的區
# ### By 岳涵

# %%
import pandas as pd
import numpy as numpy
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('NTPedu2.csv')
ch_index = df[0:1] 
ch_index #如果需要對照Column name的中文
# Out:
#   statistic_yyy site_id village  edu_age_15up_total edu_doctor_graduated_m  \
# 0          統計年     區域別     村里名稱                 總計                   博畢_男
#
#   edu_doctor_graduated_f edu_doctor_ungraduated_m edu_doctor_ungraduated_f  \
# 0                  博畢_女                     博肄_男                     博肄_女
#
#   edu_master_graduated_m edu_master_graduated_f       ...         \
# 0                  碩畢_男                   碩畢_女        ...
#
#   edu_juniorvocational_ungraduated_m edu_juniorvocational_ungraduated_f  \
# 0                              初肄_男                               初肄_女
#
#   edu_primary_graduated_m edu_primary_graduated_f edu_primary_ungraduated_m  \
# 0                   小畢_男                    小畢_女                      小肄_男
#
#   edu_primary_ungraduated_f edu_selftaughtl_m edu_selftaughtl_f  \
# 0                     小肄_女              自修_男              自修_女
#
#   edu_illiterate_m edu_illiterate_f
# 0            不識_男              不識_女
#
# [1 rows x 50 columns]

# %%
xindian = df[487:556]  #從資料中抓取新店的部分
# xindian.info() #把每個Column Name叫出來
xindian.shape #Xindian 是一個(69,50)的DataFrame，有69個里(Row,也叫Index)，每個里有50筆資料
# Out:
# (69, 50)

# %%
x10 = xindian[0:10]
# Out:
# pandas.core.frame.DataFrame

# %%
groups = ["Movies", "Sports", "Coding", "Fishing", "Dancing", "cooking"]  
num = [46, 8, 12, 12, 6, 58]

dict = {"groups": groups,  
        "num": num
       }

select_df = pd.DataFrame(dict)
print(select_df)
print(select_df.iloc[0, 1]) # 第一列第二欄：組的人數  
print("---")  
print(select_df.iloc[0:2,1:]) # 第一列：組的組名與人數  
print("---")  
# print(select_df.iloc[:,1]) # 第二欄：各組的人數  
# print("---")  
# print(select_df["num"]) # 各組的人數  
# print("---")  
# print(select_df.num) # 各組的人數
# Out:
#     groups  num
# 0   Movies   46
# 1   Sports    8
# 2   Coding   12
# 3  Fishing   12
# 4  Dancing    6
# 5  cooking   58
# 46
# ---
#    num
# 0   46
# 1    8
# ---

# %%
# %pylab inline
xum = xindian['edu_university_graduated_m'] #大學男生@新店
xuf = xindian['edu_university_graduated_f'] #大學女生@新店
xum = xum.astype(float)
xum.plot()
xuf = xuf.astype(float)
xuf.plot()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = xindian[0:70] #切出x 來做實驗，不會搞壞Xindian
xuni = x[['edu_university_graduated_m','edu_university_graduated_f']].astype(float)#要astype才能畫圖
xuni.head() #看一下這個df
# Out:
#      edu_university_graduated_m  edu_university_graduated_f
# 487                       426.0                       496.0
# 488                       473.0                       503.0
# 489                       687.0                       829.0
# 490                       621.0                       730.0
# 491                       655.0                       799.0

# %%
xuni.describe()
# Out:
#        edu_university_graduated_m  edu_university_graduated_f
# count                   69.000000                   69.000000
# mean                   444.985507                  482.985507
# std                    243.621783                  267.312963
# min                     40.000000                   32.000000
# 25%                    273.000000                  291.000000
# 50%                    417.000000                  451.000000
# 75%                    600.000000                  631.000000
# max                   1120.000000                 1190.000000

# %%
xhuni.plot.hist(stacked=True)

# %%
print(xuni.plot.bar(stacked=True))

xuni = xuni.sort_values(by=['edu_university_graduated_m']) #照男生的排序

print(xuni.plot.bar(stacked=True))
# Out:
# Axes(0.125,0.125;0.775x0.775)
# Axes(0.125,0.125;0.775x0.775)

# %%
xuni.plot.box()
#女生教育程度比較高？

# %%
ax = xuni.plot.bar(stacked=True)
# plt.savefig('./score.pdf')
# ax = s.hist()  # s is an instance of Series
fig = ax.get_figure()
fig.savefig('./score.pdf')

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

df2.plot.bar();

# %%
matplotlib.get_configdir()
# Out:
# '/Users/ah-bau/.matplotlib'

# %%
matplotlib.font_manager.FontProperties().get_family()
# Out:
# ['sans-serif']

# %%
from matplotlib import rcParams

rcParams['font.sans-serif'] = ['SimHei']

rcParams['font.family'] ='sans-serif'

# %%
import matplotlib
matplotlib.rcParams['font.sans-serif'] = 'SimHei'
# names = ["大同里","江陵里","寶興里","寶安里","信義里","忠孝里","大鵬里","太平里","頂城里"]
# xhuni = xhuni.set_index([names])

# %%
gd = pd.read_csv('grades.csv')
gd_small=gd[1:10]
gd_small = gd_small.set_index([['ㄧ','二','三','四','五','六','七','八','九']])
gd_small.plot.bar(stacked=True)
gd_small
# Out:
#     姓名  國文  英文  數學  自然  社會
# ㄧ  胡玉華  10  10  10   8   9
# 二  黃淑婷  13  15   8  11  14
# 三  陳上紫  10  10   8   9  14
# 四  崔靜成  13  12  14  12  13
# 五  張雅岳  13  12  12  12   8
# 六  梁俊翔  11  13  10  10  14
# 七  林金鳳   8   9  10  10   8
# 八  許協旺   9   9  12  10  10
# 九  郭雅惠  10  15  12  11   9

# %%
matplotlib.font_manager.FontProperties().get_family()
# Out:
# ['sans-serif']
